# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/kaggle/input/wine-dataset-for-clustering/wine-clustering.csv")

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
df.shape
# Out:
# (178, 13)

# %%
sns.heatmap(df.corr() ,annot = True , cmap = "YlGnBu" )
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans

# %%
model1 = KMeans(init = "random", n_clusters = 5, n_init = 12)
model1.fit(df)
# Out:
# KMeans(init='random', n_clusters=5, n_init=12)

# %%
np.unique(model1.labels_)
# Out:
# array([0, 1, 2, 3, 4], dtype=int32)

# %%
model1.cluster_centers_
# Out:
# array([[1.37185185e+01, 1.96814815e+00, 2.37333333e+00, 1.68925926e+01,
#         1.04666667e+02, 2.83703704e+00, 2.96444444e+00, 2.77777778e-01,
#         1.91185185e+00, 5.24333333e+00, 1.04962963e+00, 3.19222222e+00,
#         1.07240741e+03],
#        [1.39205000e+01, 1.76900000e+00, 2.49750000e+00, 1.72000000e+01,
#         1.06650000e+02, 2.90800000e+00, 3.08150000e+00, 2.95500000e-01,
#         1.90850000e+00, 6.32250000e+00, 1.11700000e+00, 3.00850000e+00,
#         1.36085000e+03],
#        [1.31776923e+01, 2.53846154e+00, 2.45269231e+00, 1.93961538e+01,
#         1.11730769e+02, 2.28192308e+00, 1.88884615e+00, 3.58846154e-01,
#         1.66076923e+00, 5.42461538e+00, 9.03692308e-01, 2.63192308e+00,
#         8.23576923e+02],
#        [1.27416667e+01, 2.68354167e+00, 2.36416667e+00, 2.06125000e+01,
#         9.71250000e+01, 1.96687500e+00, 1.32833333e+00, 4.12916667e-01,
#         1.38562500e+00, 5.54187500e+00, 8.64583333e-01, 2.18875000e+00,
#         6.36125000e+02],
# ...

# %%
model1.cluster_centers_.shape
# Out:
# (5, 13)

# %%
np.unique(model1.cluster_centers_)
# Out:
# array([2.77777778e-01, 2.95500000e-01, 3.58846154e-01, 3.83333333e-01,
#        4.12916667e-01, 8.64583333e-01, 9.03692308e-01, 9.60526316e-01,
#        1.04962963e+00, 1.11700000e+00, 1.32833333e+00, 1.38562500e+00,
#        1.46842105e+00, 1.66076923e+00, 1.76900000e+00, 1.87140351e+00,
#        1.88884615e+00, 1.90850000e+00, 1.91185185e+00, 1.96687500e+00,
#        1.96814815e+00, 2.10578947e+00, 2.18875000e+00, 2.28000000e+00,
#        2.28192308e+00, 2.32526316e+00, 2.36416667e+00, 2.37333333e+00,
#        2.45269231e+00, 2.49750000e+00, 2.53846154e+00, 2.54438596e+00,
#        2.63192308e+00, 2.68354167e+00, 2.83703704e+00, 2.90800000e+00,
#        2.96444444e+00, 3.00850000e+00, 3.08150000e+00, 3.19222222e+00,
#        3.95210525e+00, 5.24333333e+00, 5.42461538e+00, 5.54187500e+00,
#        6.32250000e+00, 1.24750877e+01, 1.27416667e+01, 1.31776923e+01,
#        1.37185185e+01, 1.39205000e+01, 1.68925926e+01, 1.72000000e+01,
# ...

# %%
plt.plot(model1.cluster_centers_)

# %%
np.array(model1.cluster_centers_)
for i in range((model1.cluster_centers_).shape[1]):
  row = np.array(model1.cluster_centers_)[:, i]  # انتخاب ردیف i
  print(row.reshape(1, -1))  # تبدیل ردیف به آرایه تک بع
# Out:
# [[13.71851852 13.9205     13.17769231 12.74166667 12.47508772]]
# [[1.96814815 1.769      2.53846154 2.68354167 2.32526316]]
# [[2.37333333 2.4975     2.45269231 2.36416667 2.28      ]]
# [[16.89259259 17.2        19.39615385 20.6125     20.63684211]]
# [[104.66666667 106.65       111.73076923  97.125       91.71929825]]
# [[2.83703704 2.908      2.28192308 1.966875   2.10578947]]
# [[2.96444444 3.0815     1.88884615 1.32833333 1.87140351]]
# [[0.27777778 0.2955     0.35884615 0.41291667 0.38333333]]
# [[1.91185185 1.9085     1.66076923 1.385625   1.46842105]]
# [[5.24333333 6.3225     5.42461538 5.541875   3.95210525]]
# [[1.04962963 1.117      0.90369231 0.86458333 0.96052632]]
# [[3.19222222 3.0085     2.63192308 2.18875    2.54438596]]
# [[1072.40740741 1360.85        823.57692308  636.125       435.57894737]]

# %%
np.array(model1.cluster_centers_)
for i in range((model1.cluster_centers_).shape[0]):
  columns = np.array(model1.cluster_centers_)[i, :]  # انتخاب ردیف i
  print(columns.reshape(1, -1))  # تبدیل ردیف به آرایه تک بع
# Out:
# [[1.37185185e+01 1.96814815e+00 2.37333333e+00 1.68925926e+01
#   1.04666667e+02 2.83703704e+00 2.96444444e+00 2.77777778e-01
#   1.91185185e+00 5.24333333e+00 1.04962963e+00 3.19222222e+00
#   1.07240741e+03]]
# [[1.39205e+01 1.76900e+00 2.49750e+00 1.72000e+01 1.06650e+02 2.90800e+00
#   3.08150e+00 2.95500e-01 1.90850e+00 6.32250e+00 1.11700e+00 3.00850e+00
#   1.36085e+03]]
# [[1.31776923e+01 2.53846154e+00 2.45269231e+00 1.93961538e+01
#   1.11730769e+02 2.28192308e+00 1.88884615e+00 3.58846154e-01
#   1.66076923e+00 5.42461538e+00 9.03692308e-01 2.63192308e+00
#   8.23576923e+02]]
# [[1.27416667e+01 2.68354167e+00 2.36416667e+00 2.06125000e+01
#   9.71250000e+01 1.96687500e+00 1.32833333e+00 4.12916667e-01
#   1.38562500e+00 5.54187500e+00 8.64583333e-01 2.18875000e+00
#   6.36125000e+02]]
# [[1.24750877e+01 2.32526316e+00 2.28000000e+00 2.06368421e+01
#   9.17192982e+01 2.10578947e+00 1.87140351e+00 3.83333333e-01
# ...

# %%
row.shape
# Out:
# (5,)

# %%
columns.shape
# Out:
# (13,)

# %%
row.reshape(-1 ,1)
# Out:
# array([[1072.40740741],
#        [1360.85      ],
#        [ 823.57692308],
#        [ 636.125     ],
#        [ 435.57894737]])

# %%
columns.reshape(-1 , 1)
# Out:
# array([[1.24750877e+01],
#        [2.32526316e+00],
#        [2.28000000e+00],
#        [2.06368421e+01],
#        [9.17192982e+01],
#        [2.10578947e+00],
#        [1.87140351e+00],
#        [3.83333333e-01],
#        [1.46842105e+00],
#        [3.95210525e+00],
#        [9.60526316e-01],
#        [2.54438596e+00],
#        [4.35578947e+02]])

# %%
plt.scatter(row , columns[:5])

# %%
from sklearn.metrics import silhouette_score

# Assuming your data is stored in X and your model is stored in kmeans
labels = model1.labels_
silhouette_avg = silhouette_score(df, labels)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.5489993239795681

# %%
import pylab
import scipy.cluster.hierarchy
from scipy.spatial import distance_matrix
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
Z_using_dist_matrix = scipy.cluster.hierarchy.linkage(df, 'complete')
fig = pylab.figure(figsize=(18,50))
def llf(id):
    return '[%s %s %s]' % (df['Alcohol'][id], df['Ash'][id], int(float(df['Malic_Acid'][id])) )

dendro = scipy.cluster.hierarchy.dendrogram(Z_using_dist_matrix,  leaf_label_func=llf, leaf_rotation=0, leaf_font_size =12, orientation = 'right')
