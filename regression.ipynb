# %% [markdown]
# # exercise from Turkish :)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("Desktop/train.csv")

# %%
train.head()
# Out:
#    deneyim  maas  yas
# 0      0.5  2500   22
# 1      0.0  2250   21
# 2      1.0  2750   23
# 3      5.0  8000   25
# 4      8.0  9000   28

# %%
train.info
# Out:
# <bound method DataFrame.info of     deneyim   maas  yas
# 0       0.5   2500   22
# 1       0.0   2250   21
# 2       1.0   2750   23
# 3       5.0   8000   25
# 4       8.0   9000   28
# 5       4.0   6900   23
# 6      15.0  20000   35
# 7       7.0   8500   29
# 8       3.0   6000   22
# 9       2.0   3500   23
# 10     12.0  15000   32
# 11     10.0  13000   30
# 12     14.0  18000   34
# 13      6.0   7500   27>

# %%
train.shape
# Out:
# (14, 3)

# %%
X1 = train.deneyim
Y = train.yas
fig1 = plt.scatter(X1 ,Y , marker = "*" , c = "blue")

# %%
X2 = train.maas
Y = train.yas
fig1 = plt.scatter(X2 ,Y , marker = "*" , c = "orange")

# %%
#deneyim = تجربه
#maas = حق الزحمه
#yas= سن

# %%
ax = sns.heatmap(train, annot=True)
ax.set(xlabel="", ylabel="")
ax.xaxis.tick_top()

# %%
X3 = train.yas
Y = train.maas
fig1 = plt.scatter(X3 ,Y , marker = "*" , c = "black")

# %%
X4 = train.deneyim
Y = train.maas
fig1 = plt.scatter(X4 ,Y , marker = "*" , c = "black")

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , random_state = 2 , test_size = 0.2)

# %%
X_train
# Out:
# 0      0.5
# 9      2.0
# 3      5.0
# 1      0.0
# 10    12.0
# 7      7.0
# 12    14.0
# 2      1.0
# 6     15.0
# 13     6.0
# 8      3.0
# Name: deneyim, dtype: float64

# %%
X_test
# Out:
# 11    10.0
# 4      8.0
# 5      4.0
# Name: deneyim, dtype: float64

# %%
model =  LinearRegression()

# %%
model.fit(X_train.values.reshape(-1 ,1) , Y_train.values.reshape(-1 ,1))
# Out:
# LinearRegression()

# %%
model_predict = model.predict(X_test.values.reshape(-1 ,1))

# %%
plt.scatter(X , Y , marker = "*" , c = "blue")
plt.plot(X_test.values.reshape(-1 , 1) , model.predict(X_test.values.reshape(-1 ,1)))

# %%
score = model.score(X.values.reshape(-1 ,1) , Y.values.reshape(-1 ,1))

# %%
score
# Out:
# 0.9769208294615037
