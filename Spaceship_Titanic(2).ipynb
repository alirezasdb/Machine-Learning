# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/train.csv")

# %%
df.head(20)
# Out:
#    PassengerId HomePlanet CryoSleep  Cabin    Destination   Age    VIP  \
# 0      0001_01     Europa     False  B/0/P    TRAPPIST-1e  39.0  False
# 1      0002_01      Earth     False  F/0/S    TRAPPIST-1e  24.0  False
# 2      0003_01     Europa     False  A/0/S    TRAPPIST-1e  58.0   True
# 3      0003_02     Europa     False  A/0/S    TRAPPIST-1e  33.0  False
# 4      0004_01      Earth     False  F/1/S    TRAPPIST-1e  16.0  False
# 5      0005_01      Earth     False  F/0/P  PSO J318.5-22  44.0  False
# 6      0006_01      Earth     False  F/2/S    TRAPPIST-1e  26.0  False
# 7      0006_02      Earth      True  G/0/S    TRAPPIST-1e  28.0  False
# 8      0007_01      Earth     False  F/3/S    TRAPPIST-1e  35.0  False
# 9      0008_01     Europa      True  B/1/P    55 Cancri e  14.0  False
# 10     0008_02     Europa      True  B/1/P    TRAPPIST-1e  34.0  False
# 11     0008_03     Europa     False  B/1/P    55 Cancri e  45.0  False
# ...

# %%
df.isna().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head(20)
# Out:
#    PassengerId HomePlanet CryoSleep  Cabin    Destination   Age    VIP  \
# 0      0001_01     Europa     False  B/0/P    TRAPPIST-1e  39.0  False
# 1      0002_01      Earth     False  F/0/S    TRAPPIST-1e  24.0  False
# 2      0003_01     Europa     False  A/0/S    TRAPPIST-1e  58.0   True
# 3      0003_02     Europa     False  A/0/S    TRAPPIST-1e  33.0  False
# 4      0004_01      Earth     False  F/1/S    TRAPPIST-1e  16.0  False
# 5      0005_01      Earth     False  F/0/P  PSO J318.5-22  44.0  False
# 6      0006_01      Earth     False  F/2/S    TRAPPIST-1e  26.0  False
# 8      0007_01      Earth     False  F/3/S    TRAPPIST-1e  35.0  False
# 9      0008_01     Europa      True  B/1/P    55 Cancri e  14.0  False
# 11     0008_03     Europa     False  B/1/P    55 Cancri e  45.0  False
# 12     0009_01       Mars     False  F/1/P    TRAPPIST-1e  32.0  False
# 13     0010_01      Earth     False  G/1/S    TRAPPIST-1e  48.0  False
# ...

# %%
df.shape
# Out:
# (6606, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6606 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   6606 non-null   object
#  1   HomePlanet    6606 non-null   object
#  2   CryoSleep     6606 non-null   object
#  3   Cabin         6606 non-null   object
#  4   Destination   6606 non-null   object
#  5   Age           6606 non-null   float64
#  6   VIP           6606 non-null   object
#  7   RoomService   6606 non-null   float64
#  8   FoodCourt     6606 non-null   float64
#  9   ShoppingMall  6606 non-null   float64
#  10  Spa           6606 non-null   float64
#  11  VRDeck        6606 non-null   float64
#  12  Name          6606 non-null   object
#  13  Transported   6606 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 729.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit_transform(df.Transported)
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %%
Transported = df["Transported"].value_counts()
plt.bar("True",Transported[1])
plt.bar("False",Transported[0])
# Out:
# <BarContainer object of 1 artists>

# %%
df.Transported = le.fit_transform(df.Transported)

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
X = df.drop(columns = "Transported")

# %%
Y = df["Transported"]

# %%
X
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
Y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 8688    0
# 8689    0
# 8690    1
# 8691    0
# 8692    1
# Name: Transported, Length: 6606, dtype: int64

# %%
df.VIP = le.fit_transform(df.VIP)

# %%
df.CryoSleep = le.fit_transform(df.CryoSleep)

# %%
le = LabelEncoder()
for i in X.columns:
  X[i] = le.fit_transform(X[i])
Y = le.fit_transform(Y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , random_state = 2 , test_size = 0.2)

# %%
X_train
# Out:
#       PassengerId  HomePlanet  CryoSleep  Cabin  Destination  Age  VIP  \
# 827           622           1          0   1129            2   41    0
# 3395         2555           0          1   4815            2   28    0
# 7502         5678           1          0    366            2   29    0
# 8187         6220           0          0   2732            2   27    0
# 2002         1494           2          0   3049            0    4    0
# ...           ...         ...        ...    ...          ...  ...  ...
# 3338         2514           0          0   1337            2   22    0
# 8479         6443           2          0   1115            2   26    0
# 4779         3606           0          0   1872            0   51    0
# 7536         5704           1          1    370            2   65    0
# 3421         2575           2          0   3345            2    0    0
#
#       RoomService  FoodCourt  ShoppingMall  Spa  VRDeck  Name
# ...

# %%
X_test
# Out:
#       PassengerId  HomePlanet  CryoSleep  Cabin  Destination  Age  VIP  \
# 5968         4508           0          0   3741            2   40    0
# 2514         1877           0          1   4614            1   20    0
# 3432         2584           2          1   1345            2   32    0
# 3223         2420           0          1   4780            0   16    0
# 6606         4999           1          1    702            0   17    0
# ...           ...         ...        ...    ...          ...  ...  ...
# 720           545           0          1   3875            1   30    0
# 7206         5448           2          0   2498            2   39    0
# 8477         6441           0          0   2677            2   16    0
# 475           360           1          0   1004            0   32    0
# 1689         1261           0          0   1240            2   39    0
#
#       RoomService  FoodCourt  ShoppingMall  Spa  VRDeck  Name
# ...

# %%
# use classification model ...

# %%
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier(n_neighbors = 8 , metric = "minkowski" , p=2)

# %%
model1.fit(X_train , Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
score = model1.score(X , Y)

# %%
score
# Out:
# 0.7783832879200726

# %%
model1_p = model1.predict(X_train)

# %%
model1_p.shape
# Out:
# (5284,)

# %%
import pylab
import scipy.cluster.hierarchy
from scipy.spatial import distance_matrix
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
sns.heatmap(X_test , annot = True)
# Out:
# <Axes: >
# Error in callback <function flush_figures at 0x7dbfaac243a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
import plotly.graph_objects as go
from sklearn.datasets import make_moons
from sklearn.neighbors import KNeighborsClassifier

mesh_size = .02
margin = 0.25

# Load and split data
X, y = make_moons(noise=0.3, random_state=0)

# Create a mesh grid on which we will run our model
x_min, x_max = X[:, 0].min() - margin, X[:, 0].max() + margin
y_min, y_max = X[:, 1].min() - margin, X[:, 1].max() + margin
xrange = np.arange(x_min, x_max, mesh_size)
yrange = np.arange(y_min, y_max, mesh_size)
xx, yy = np.meshgrid(xrange, yrange)

# Create classifier, run predictions on grid
clf = KNeighborsClassifier(15, weights='uniform')
clf.fit(X, y)
Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
Z = Z.reshape(xx.shape)


# Plot the figure
fig = go.Figure(data=[
    go.Contour(
        x=xrange,
        y=yrange,
        z=Z,
        colorscale='RdBu'
    )
])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets


X = X[:, :2]
y = y
h = .02

cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#00AAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#00AAFF'])

clf = neighbors.KNeighborsClassifier(8, weights='distance')
clf.fit(X, y)

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("2-Class classification (k = %i)" % (8))
plt.show()

# %%
output = pd.DataFrame({
    "PassengerId" : X_test.PassengerId,
    "Transported" : model1.predict(X_test)

})

output["Transported"] = output["Transported"].replace({1:"True" , 0:"False"})

# %%
output['PassengerId'] = output['PassengerId'].astype('|S')

# %%
output["PassengerId"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1322 entries, 5968 to 1689
# Series name: PassengerId
# Non-Null Count  Dtype
# --------------  -----
# 1322 non-null   |S21
# dtypes: object(1)
# memory usage: 37.4+ KB

# %%
output.to_csv('output1.csv' , index = False)

# %%
o = pd.read_csv("/content/output.csv")

# %%
o
# Out:
#      PassengerId  Transported
# 0        b'4508'         True
# 1        b'1877'         True
# 2        b'2584'        False
# 3        b'2420'        False
# 4        b'4999'         True
# ...          ...          ...
# 1317      b'545'         True
# 1318     b'5448'         True
# 1319     b'6441'        False
# 1320      b'360'         True
# 1321     b'1261'         True
#
# [1322 rows x 2 columns]

# %%
# @title Transported

from matplotlib import pyplot as plt
import seaborn as sns
o.groupby('Transported').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
test_df = pd.read_csv('/content/test.csv')

# %%
submission_id = test_df.PassengerId

# %%
# Replace NaN values with zero
test_df[['VIP', 'CryoSleep']] = test_df[['VIP', 'CryoSleep']].fillna(value=0)

# %%
# Creating New Features - Deck, Cabin_num and Side from the column Cabin and remove Cabin
test_df[["Deck", "Cabin_num", "Side"]] = test_df["Cabin"].str.split("/", expand=True)
test_df = test_df.drop('Cabin', axis=1)

# %%
# Convert boolean to 1's and 0's
test_df['VIP'] = test_df['VIP'].astype(int)
test_df['CryoSleep'] = test_df['CryoSleep'].astype(int)

# %%
sample_submission_df = pd.read_csv('/content/sample_submission.csv')

# %%
np.unique(sample_submission_df['Transported']) == model1_p
sample_submission_df.shape
# Out:
# (4277, 2)

# %%
sample_submission_df.to_csv('/content/sample_submission.csv', index=False)
