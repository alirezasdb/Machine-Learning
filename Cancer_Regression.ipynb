# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/cancer_reg.csv")

# %%
df.head(10)
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
# 5        428.0               152             176.0          505.4      52313
# 6        250.0                97             175.9          461.8      37782
# 7        146.0                71             183.6          404.0      40189
# 8         88.0                36             190.5          459.4      42579
# 9       4025.0              1380             177.8          510.9      60397
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# ...

# %%
df2 = pd.read_csv("/content/avg-household-size.csv")

# %%
df2.head(10)
# Out:
#    statefips  countyfips  avghouseholdsize  \
# 0          2          13              2.43
# 1          2          16              3.59
# 2          2          20              2.77
# 3          2          50              3.86
# 4          2          60              2.50
# 5          2          68              2.34
# 6          2          70              3.56
# 7          2          90              2.69
# 8          2         100              2.12
# 9          2         105              2.26
#
#                               geography
# 0        Aleutians East Borough, Alaska
# 1    Aleutians West Census Area, Alaska
# 2        Anchorage Municipality, Alaska
# 3            Bethel Census Area, Alaska
# 4           Bristol Bay Borough, Alaska
# 5                Denali Borough, Alaska
# 6        Dillingham Census Area, Alaska
# 7  Fairbanks North Star Borough, Alaska
# 8                Haines Borough, Alaska
# 9     Hoonah-Angoon Census Area, Alaska

# %%
df.isna().sum()
# Out:
# avganncount                   0
# avgdeathsperyear              0
# target_deathrate              0
# incidencerate                 0
# medincome                     0
# popest2015                    0
# povertypercent                0
# studypercap                   0
# binnedinc                     0
# medianage                     0
# medianagemale                 0
# medianagefemale               0
# geography                     0
# percentmarried                0
# pctnohs18_24                  0
# pcths18_24                    0
# pctsomecol18_24            2285
# pctbachdeg18_24               0
# pcths25_over                  0
# pctbachdeg25_over             0
# pctemployed16_over          152
# pctunemployed16_over          0
# pctprivatecoverage            0
# pctprivatecoveragealone     609
# pctempprivcoverage            0
# pctpubliccoverage             0
# pctpubliccoveragealone        0
# pctwhite                      0
# pctblack                      0
# ...

# %%
df = df.fillna(value=None, method="ffill")

# %%
df.describe()
# Out:
#         avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medincome    popest2015  povertypercent  studypercap    medianage  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avganncount              3047 non-null   float64
#  1   avgdeathsperyear         3047 non-null   int64
#  2   target_deathrate         3047 non-null   float64
#  3   incidencerate            3047 non-null   float64
#  4   medincome                3047 non-null   int64
#  5   popest2015               3047 non-null   int64
#  6   povertypercent           3047 non-null   float64
#  7   studypercap              3047 non-null   float64
#  8   binnedinc                3047 non-null   object
#  9   medianage                3047 non-null   float64
#  10  medianagemale            3047 non-null   float64
#  11  medianagefemale          3047 non-null   float64
#  12  geography                3047 non-null   object
#  13  percentmarried           3047 non-null   float64
# ...

# %%
df.shape
# Out:
# (3047, 33)

# %%
#############################

# %%
df2.isna().sum()
# Out:
# statefips           0
# countyfips          0
# avghouseholdsize    0
# geography           0
# dtype: int64

# %%
df_finall = df.merge(df2)

# %%
df_finall.head(10)
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
# 5        428.0               152             176.0          505.4      52313
# 6        250.0                97             175.9          461.8      37782
# 7        146.0                71             183.6          404.0      40189
# 8         88.0                36             190.5          459.4      42579
# 9       4025.0              1380             177.8          510.9      60397
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_finall.corr(numeric_only=True) , annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.histplot(data=df_finall, x='target_deathrate', bins=30, kde=True, color='red')
plt.title('Distribution of Target Death Rate due to Cancer')
plt.xlabel('Target Death Rate')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data = df_finall , x ="pctblack" ,  y = "birthrate" , color = "black")
plt.title('pctblack vs. Target Death Rate')
plt.xlabel('pctblack')
plt.ylabel('birthrate')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data = df_finall , x ="pctwhite" ,  y = "birthrate" , color = "purple")
plt.title('pctblack vs. Target Death Rate')
plt.xlabel('pctwhite')
plt.ylabel('birthrate')
plt.show()

# %%
df_finall_sort = df_finall.sort_values(by = "povertypercent" , ascending = False)

# %%
top_20 = df_finall_sort.head(20)
plt.figure(figsize = (10,6))
sns.barplot(data = top_20 ,  x='povertypercent', y='geography', palette='Set2')
plt.show()
# Out:
# <ipython-input-22-b56e29e56478>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top_20 ,  x='povertypercent', y='geography', palette='Set2')

# %%
#############################################################################

# %%
X = df_finall.drop(columns = "birthrate")
X = df_finall.drop(columns = "geography")
Y = df_finall["birthrate"]

# %%
X
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medincome  popest2015  povertypercent  studypercap           binnedinc  \
# ...

# %%
Y
# Out:
# 0       6.118831
# 1       4.333096
# 2       3.729488
# 3       4.603841
# 4       6.796657
#           ...
# 3042    7.773512
# 3043    8.186470
# 3044    7.809192
# 3045    7.582938
# 3046    8.981723
# Name: birthrate, Length: 3047, dtype: float64

# %%
params = {'random_strength': 1 , 'n_estimators': 100,'max_depth': 7 , 'loss_function':'RMSE' , 'learning_rate' : 0.1 ,  'colsample_bylevel': 0.8,
         'bootstrap_type': 'MVS', 'bagging_temperature': 1.0}

# %%
# !pip install catboost
import catboost

# %%
from catboost import CatBoostRegressor
model1 = CatBoostRegressor(**params)
X = X.select_dtypes(include = ['float64' , 'int64'])
model1.fit(X , Y)
# Out:
# 0:	learn: 1.8347956	total: 62.2ms	remaining: 6.16s
# 1:	learn: 1.6890205	total: 89.5ms	remaining: 4.38s
# 2:	learn: 1.5506651	total: 122ms	remaining: 3.93s
# 3:	learn: 1.4380994	total: 141ms	remaining: 3.39s
# 4:	learn: 1.3315632	total: 177ms	remaining: 3.37s
# 5:	learn: 1.2291911	total: 193ms	remaining: 3.03s
# 6:	learn: 1.1270068	total: 214ms	remaining: 2.84s
# 7:	learn: 1.0419072	total: 238ms	remaining: 2.74s
# 8:	learn: 0.9683443	total: 261ms	remaining: 2.63s
# 9:	learn: 0.9060329	total: 291ms	remaining: 2.62s
# 10:	learn: 0.8426835	total: 322ms	remaining: 2.6s
# 11:	learn: 0.7864264	total: 350ms	remaining: 2.56s
# 12:	learn: 0.7268018	total: 375ms	remaining: 2.51s
# 13:	learn: 0.6835661	total: 403ms	remaining: 2.48s
# 14:	learn: 0.6331104	total: 444ms	remaining: 2.51s
# 15:	learn: 0.5959857	total: 480ms	remaining: 2.52s
# 16:	learn: 0.5560832	total: 514ms	remaining: 2.51s
# 17:	learn: 0.5226269	total: 538ms	remaining: 2.45s
# 18:	learn: 0.4865659	total: 572ms	remaining: 2.44s
# ...

# %%
model1_predict = model1.predict(X)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print("MSE: ", mean_squared_error(Y, model1_predict))
print("MAE: ", mean_absolute_error(Y, model1_predict))
print("R2: ", r2_score(Y, model1_predict))
print("RMSE: ", mean_squared_error(Y, model1_predict, squared=False))
# Out:
# MSE:  0.007194850486644925
# MAE:  0.060947416301794295
# R2:  0.9981749011705604
# RMSE:  0.08482246451645298

# %%
model1_score = model1.score(X,Y)
model1_score
# Out:
# 0.9981749011705604

# %%
plt.scatter(Y,model1_predict, marker = '*' , c = 'red')
plt.plot([min(Y), max(Y)], [min(Y), max(Y)],linestyle='--', color='black', linewidth=2)
plt.xlabel("original Values")
plt.ylabel("Predict")
plt.title("Catboost Regressor Predictions & True Values")
plt.show()

# %%
################################
#https://www.kaggle.com/geek1it
#https://github.com/alirezasdb/Machine-Learning/tree/main
