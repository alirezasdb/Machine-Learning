# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !kaggle datasets download -d sasikumarg/multiple-sclerosis-2016
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sasikumarg/multiple-sclerosis-2016
# License(s): unknown
# ...
# 100% 605M/607M [00:33<00:00, 21.4MB/s]
# 100% 607M/607M [00:33<00:00, 19.3MB/s]

# %% [markdown]
# Here's what each of these libraries and components does:
#
#     interact:
#     This function automatically generates UI controls (widgets) like sliders, checkboxes, etc., for function parameters, allowing you to interactively change them and see the results immediately. It will automatically detect the appropriate widget based on the type of the argument.
#
# interactive:
# Similar to interact, but it gives you more flexibility. It allows you to create widgets without immediately displaying the result. You can control when the result is displayed and how the output is handled.
# This creates sliders for both a and b, and displays their sum based on the user’s input.
#
# IntSlider:
# This widget creates a slider for integer values. It allows users to select a numerical value by sliding a control.
#
# ToggleButtons:
# This widget creates a group of buttons where only one can be selected at a time. It is useful for letting users choose between different options.
#
# The function montage from the skimage.util module in the scikit-image library is used to create a montage (a composite image) from multiple individual images. It arranges a collection of images into a single larger image, often in a grid format.
# Purpose:
#
# It is particularly useful for visualizing multiple images at once, especially in machine learning and medical imaging, where you might want to inspect multiple slices or different parts of a dataset at the same time.
# Key Parameters:
#
#     rescale_intensity: This parameter controls whether to rescale the image intensities to the range [0, 1], which is useful for consistent visualization when working with images of different intensities.
#     grid_shape: You can specify the grid shape (rows, columns) in which the images will be arranged. If not specified, it automatically tries to make the montage as square as possible.
#
# In summary, the montage function is a convenient way to visually compare multiple images by arranging them into a single, composite view.
#
#
# The rotate function from the skimage.transform module in the scikit-image library is used to rotate an image by a specified angle.
# Purpose:
#
# This function is useful for rotating images, which is commonly needed in image processing, machine learning, and preparing images for further analysis.
# The rotate function from the skimage.transform module in the scikit-image library is used to rotate an image by a specified angle.
# Purpose:
#
# This function is useful for rotating images, which is commonly needed in image processing, machine learning, and preparing images for further analysis.
# Example:
#
# python
#
# from skimage.transform import rotate
# import matplotlib.pyplot as plt
# from skimage import data
#
# # Sample image from the skimage library
# image = data.camera()
#
# # Rotate the image by 45 degrees
# rotated_image = rotate(image, angle=45)
#
# # Display the original and rotated images
# fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# ax[0].imshow(image, cmap='gray')
# ax[0].set_title('Original Image')
#
# ax[1].imshow(rotated_image, cmap='gray')
# ax[1].set_title('Rotated Image')
#
# plt.show()
#
# Key Parameters:
#
#     angle: The angle by which the image will be rotated, measured in degrees.
#     resize: If True, the output image will be resized to fit the entire rotated image. If False, parts of the image may be cropped after rotation.
#     mode: Specifies how pixels outside the boundaries of the image are handled after rotation. Options include constant, edge, wrap, and others.
#
# Summary:
#
# The rotate function is a simple way to rotate images by a given angle. It also provides options for resizing the output and handling pixels that fall outside the image boundaries during rotation.
#
# ##
# The nilearn library is a powerful tool designed for analyzing neuroimaging data, with a focus on fMRI and MRI data. It builds on top of libraries like scikit-learn to facilitate machine learning and statistical analysis of brain imaging data.
# Main Uses of nilearn:
#
#     fMRI Analysis: It allows you to process and analyze functional brain imaging data (fMRI), including performing correlation analyses or creating brain activation maps.
#     Visualization of MRI Data: nilearn provides tools for visualizing 3D brain images, statistical maps, and brain regions.
#     Feature Extraction: The library helps extract relevant features from brain images that can be used for machine learning and classification tasks.
#     Statistical Modeling: It supports a variety of statistical modeling techniques for interpreting neuroimaging data.
#
# Key Features:
#
#     Visualization: Powerful tools for displaying MRI, fMRI, and statistical brain images in 3D and 4D formats.
#     Masking: Functions to extract brain masks or specific regions of interest (ROI) from brain images.
#     Statistical Analysis: Built-in functions to perform statistical analysis on neuroimaging data.
#     Easy Integration with scikit-learn: Seamlessly integrates with scikit-learn for applying machine learning techniques to neuroimaging data.
#
# Advantages:
#
#     Ease of Use: nilearn is designed to be user-friendly, even for those who may not be experts in machine learning or neuroimaging.
#     Integration: It works well with other libraries such as scikit-learn, matplotlib, and nibabel.
#     Advanced Analysis: Allows complex neuroimaging analyses with customizable and ready-to-use tools.
#
# In summary, nilearn is a robust tool for performing neuroimaging data analysis, designed to be accessible to both beginners and advanced researchers in the field of brain imaging.
#
# ###
# The statement import keras.backend as K imports the backend functions of the Keras deep learning library, allowing you to access lower-level operations that are executed by the underlying deep learning framework (TensorFlow, Theano, or CNTK).
# Purpose:
#
# Keras provides a high-level API for building neural networks, but the backend functions give you access to the low-level computational operations such as tensor manipulations, mathematical operations, and model functions. These are useful for creating custom operations, metrics, or layers that are not directly available in Keras.
# Key Features of keras.backend:
#
#     Tensor Operations: You can perform operations like addition, multiplication, reshape, etc., on tensors (multidimensional arrays).
#     Mathematical Functions: Functions like K.sum(), K.mean(), K.sqrt(), etc., for various mathematical computations on tensors.
#     Custom Losses and Metrics: You can define custom loss functions or metrics by combining these backend functions.
#     Model Functions: Backend provides methods for model-level operations like K.clear_session() to free up memory, or K.learning_phase() to check whether the model is in training or inference mode.
#     Device Operations: Set operations for CPU or GPU-specific computations.
#
#
# Commonly Used Functions:
#
#     K.dot(x, y): Matrix multiplication between two tensors.
#     K.sum(x): Sum of all elements in a tensor.
#     K.argmax(x): Returns the index of the maximum value in a tensor.
#     K.reshape(x, shape): Reshapes a tensor into a new shape.
#     K.learning_phase(): Returns whether the model is in training or testing phase.
#
# Why Use keras.backend?
#
#     Customization: When predefined layers, losses, or metrics are not sufficient, the backend allows you to implement custom functionality.
#     Advanced Control: You can directly manipulate tensors and computations for fine-tuning models or optimizing specific tasks.
#
# In summary, keras.backend provides access to lower-level operations, enabling you to have more control and flexibility when building and customizing deep learning models.
#
# ###
#
# Callback that streams epoch results to a CSV file.
#
# Supports all values that can be represented as a string, including 1D iterables such as np.ndarray.
#
# ###
#
# Transform features by scaling each feature to a given range.
#
# This estimator scales and translates each feature individually such that it is in the given range on the training set, e.g. between zero and one.
#
# ####
#
#
# tensorflow.keras.callbacks:
#
#     ModelCheckpoint:
#     This callback is used to save the model during training. You can configure it to save the model at the end of each epoch, and only save the model if it improves, for example based on validation loss or accuracy. This is helpful for keeping the best version of the model.
#         Main use: Save the best model during training.
#
# ReduceLROnPlateau:
# This callback reduces the learning rate when the model stops improving. If the validation loss does not improve for a certain number of epochs, the learning rate is reduced by a specified factor. This helps the model to converge better and avoid getting stuck in local minima.
#
#     Main use: Automatically reduce the learning rate when the model stops improving.
#
# EarlyStopping:
# This callback is used to stop training early if the model stops improving. For example, if the validation loss does not improve for a specified number of epochs (patience), the training is stopped. This helps prevent overfitting and saves time.
#
#     Main use: Stop training when the model is no longer improving.
#
#
# TensorBoard:
# This callback allows you to log and visualize metrics during training in TensorBoard. It tracks metrics like loss, accuracy, and generates plots that can be visualized in real-time, providing insight into the training process.
#
#     Main use: Monitor and visualize training metrics in TensorBoard.
#
# Conclusion:
#
# These callbacks work together to enhance the training process, by saving the best model, adjusting the learning rate dynamically, stopping training when overfitting, and providing real-time visual feedback through TensorBoard.
#
#
# ###
# tensorflow.keras.layers.experimental.preprocessing: This is part of the TensorFlow library, specifically from the Keras API's experimental layers. The preprocessing module includes layers used for preprocessing data (usually images, text, or sequences) before feeding them into a neural network model. Some of the common preprocessing layers include:
#
#     Rescaling: To rescale pixel values.
#     Normalization: To normalize data to a certain range.
#     RandomFlip, RandomRotation, etc.: For augmenting images by flipping, rotating, or applying other transformations randomly.
#
# These layers can be useful for preparing input data directly in the model pipeline, making the model more robust and reducing overfitting.
# ####
# cv2 (OpenCV): This is part of the OpenCV library, a popular computer vision library. cv2 provides a wide range of functions to work with images and videos, including reading, writing, transforming, and analyzing images.

# %%
import nibabel as nib
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
from skimage.util import montage
from skimage.transform import rotate
##################
# !pip install nilearn
import nilearn as nl
import nilearn.plotting as nlp
# %matplotlib inline
##################
import keras
import keras.backend as k
from keras.callbacks import CSVLogger
##################
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
##################
from tensorflow.keras.callbacks import ModelCheckpoint , ReduceLROnPlateau , EarlyStopping , TensorBoard
##################
from tensorflow.keras.layers import Rescaling, RandomFlip, RandomRotation
##################
import cv2

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import segmentation_models as sm
from tensorflow.keras.utils import get_file, to_categorical
import sys
import os
import glob #find filles in path by the same algorithms ... exp: end of it is: .txt
import time
from mpl_toolkits.axes_grid1 import ImageGrid #creating network or plot of some images together :)
####
from segmentation_models import Unet, Linknet, PSPNet, FPN
from segmentation_models.utils import set_trainable #for using pre-trained model , on/off some layers & ...
from torch.utils.data import Dataset
from keras.models import load_model
from tensorflow.keras import utils as np_utils #for categorical to OneHotClass & ...
# !pip install pillow
import PIL
from PIL import Image , ImageOps
import shutil #managing files & directories
####
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize

# %%
import zipfile
import os
import nibabel as nib

# 1. مسیر فایل زیپ و پوشه استخراج
zip_file_path = '/content/multiple-sclerosis-2016.zip'
extracted_folder_path = '/content/multiple-sclerosis-2016/'

# 2. استخراج فایل زیپ
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# 3. بارگذاری تصاویر NIfTI از پوشه استخراج شده
def load_nifti_image(file_name):
    file_path = os.path.join(extracted_folder_path, file_name)
    return nib.load(file_path).get_fdata()

# تصاویر مورد نظر را بارگذاری کنید
test_image_flair = load_nifti_image('MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii')
test_image_t1 = load_nifti_image('MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_T1_preprocessed.nii')
test_image_t2 = load_nifti_image('MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_T2_preprocessed.nii')
test_image_dp = load_nifti_image('MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_DP_preprocessed.nii')
test_image_Brain_Mask = load_nifti_image('MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_Consensus.nii')

# نمایش ابعاد تصاویر برای بررسی
print("FLAIR Image shape:", test_image_flair.shape)
print("T1 Image shape:", test_image_t1.shape)
print("T2 Image shape:", test_image_t2.shape)
print("DP Image shape:", test_image_dp.shape)
print("Brain Mask Image shape:", test_image_Brain_Mask.shape)
# Out:
# FLAIR Image shape: (240, 256, 512)
# T1 Image shape: (240, 256, 512)
# T2 Image shape: (240, 256, 512)
# DP Image shape: (240, 256, 512)
# Brain Mask Image shape: (240, 256, 512)

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w =280
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_dp[:,:,test_image_dp.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image dp')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_image_Brain_Mask[:,:,test_image_Brain_Mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
################################################################################

# %%
SEGMENT_CLASS ={
    0 : 'NOT MS' ,
    1 : 'MS'
}
VOLUME_SLICES = 180
VOLUME_START_AT = 300

# %%
import zipfile
import os
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# Define paths
zip_file_path = '/content/multiple-sclerosis-2016.zip'
extracted_folder_path = '/content/multiple-sclerosis-2016/'

# Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# Updated values for volume slices and starting slice
VOLUME_START_AT = 260
VOLUME_SLICES = 250

def getBrainSizeForVolume(image_volume):
    total = 0
    for i in range(VOLUME_SLICES):
        arr = image_volume[:, :, i + VOLUME_START_AT].flatten()
        image_count = np.count_nonzero(arr)
        total += image_count
    return total

# Load the MRI data from the extracted folder
example_volume = nib.load(extracted_folder_path + 'MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii').get_fdata()

# Display selected slices
f, axarr = plt.subplots(1, 2, figsize=(8, 10))
axarr[0].imshow(example_volume[:, :, VOLUME_START_AT], cmap='gray')
axarr[0].set_title('Slice at Start')
axarr[1].imshow(example_volume[:, :, VOLUME_START_AT + 30], cmap='gray')
axarr[1].set_title('Slice at Start + 30')

for ax in axarr:
    ax.axis('off')

plt.show()

# Calculate and display the total count of non-zero pixels
total_count = getBrainSizeForVolume(example_volume)
print(f'Total count of non-zero pixels: {total_count}')
# Out:
# Total count of non-zero pixels: 3943435

# %% [markdown]
# Here is an explanation and code for processing MRI image data with the given variables and functions. The code involves loading MRI data, displaying specific slices from the volume, and calculating the total count of non-zero pixels to estimate the brain size in the MRI volume.
# Explanation of the Code
#
#     Variables:
#         SEGMENT_CLASSES: A dictionary that maps segmentation class IDs to class names.
#
#     VOLUME_SLICES: The number of slices (2D images) to process from the 3D volume.
#     VOLUME_START_AT: The starting index for the slices in the volume.
#
# Note: You redefined VOLUME_SLICES and VOLUME_START_AT, so these new values will be used.
#
# getBrainSizeForVolume Function:
#
#     This function calculates the total number of non-zero pixels across specified slices of the MRI volume.
#     image_volume is the 3D volume data loaded from the MRI images.
#     For each slice from VOLUME_START_AT to VOLUME_START_AT + VOLUME_SLICES, the pixels are flattened into a 1D array, and the count of non-zero pixels is calculated using np.count_nonzero().
#     The function returns the total count of non-zero pixels.
#
# Loading and Displaying Data:
#
#     Load MRI data using nibabel.
#     Display specific slices from the 3D volume using matplotlib.
#
#
# Additional Details:
#
#     Loading and Displaying Images:
#         example_volume contains the 3D MRI data as a NumPy array.
#         Slices at indices VOLUME_START_AT and VOLUME_START_AT + 30 are displayed using matplotlib.
#
#     Calculating Non-Zero Pixels:
#         The getBrainSizeForVolume function calculates the total count of non-zero pixels, which is used to estimate the size of the brain or other regions of interest in the MRI volume.
#
# This code allows you to visualize specific slices from the MRI volume and compute the total number of non-zero pixels across the selected slices, which can be useful for analyzing the extent of brain lesions or other features in MRI data.

# %%
f, axarr = plt.subplots(1,2, figsize = (8, 10))
axarr[0].imshow(example_volume[:,:,VOLUME_START_AT])
axarr[1].imshow(example_volume[:,:,VOLUME_START_AT+30])

# %%
#########################################################

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,30))
ax1.imshow(rotate(montage(test_image_Brain_Mask[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %% [markdown]
#     Extract a specific range of slices from the 3D volume.
#     Create a montage of these slices.
#     Rotate the montage image.
#     Display the final image using matplotlib.
#
# Here’s a breakdown of each component and how you might implement it, along with any necessary modifications or additional imports:
# Explanation
#
#     Extract a Specific Range of Slices:
#         test_image_Brain_Mask[50:-50,:,:]: Extracts slices from index 50 to -50 (i.e., all slices from 50 to -50 along the z-axis).
#
#     Create a Montage:
#         montage(): Combines the selected slices into a single image. This function is not directly available in matplotlib or numpy, so you need to implement or import a montage function.
#
#     Rotate the Image:
#         rotate(): Rotates the montage image. You can use scikit-image's rotate function.
#
#     Display the Image:
#         Using matplotlib to display the final image.

# %%
import nibabel as nib
import nilearn as nl
import nilearn.plotting as nlplt
import matplotlib.pyplot as plt
import zipfile
import os

# Define paths
zip_file_path = '/content/multiple-sclerosis-2016.zip'
extracted_folder_path = '/content/multiple-sclerosis-2016/'

# Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# Define paths to the extracted files
flair_image_path = os.path.join(extracted_folder_path, 'MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii')
consensus_mask_path = os.path.join(extracted_folder_path, 'MSSEG2016_TrainingData_Patient_02/MSSEG2016_TrainingData_Patient_02_Consensus.nii')

# Load images using nilearn
niimg = nl.image.load_img(flair_image_path)
nimask = nl.image.load_img(consensus_mask_path)

# Create subplots for visualization
fig, axes = plt.subplots(nrows=4, figsize=(30, 40))

# Plot anatomical image
nlplt.plot_anat(niimg,
                title='MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii plot_anat',
                axes=axes[0])

# Plot EPI image
nlplt.plot_epi(niimg,
               title='MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii plot_epi',
               axes=axes[1])

# Plot general image
nlplt.plot_img(niimg,
               title='MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii plot_img',
               axes=axes[2])

# Plot ROI with mask
nlplt.plot_roi(nimask,
               title='MSSEG2016_TrainingData_Patient_02_FLAIR_preprocessed.nii with mask plot_roi',
               bg_img=niimg,
               axes=axes[3], cmap='Paired')

# Show the plots
plt.show()

# %%
##################################################

# %% [markdown]
# Overview
#
# The code defines several evaluation metrics commonly used in machine learning and image segmentation tasks. These metrics include the Dice Coefficient, Precision, Sensitivity, and Specificity.
# Explanation of Functions
#
#     Dice Coefficient:
#
#         Purpose: Measures the similarity between the predicted segmentation and the ground truth. It's particularly useful for evaluating segmentation quality in medical imaging.
#
#
#     Parameters:
#         y_true: The ground truth values.
#         y_pred: The predicted values.
#         smooth: A constant added to avoid division by zero.
#     Output: The average Dice Coefficient for all classes.
#
# Parameters:
#
#     y_true: The ground truth values.
#     y_pred: The predicted values.
#     epsilon: A small constant to prevent division by zero.
#
# Output: The Dice Coefficient for a specific class (class 1).
#
#
# Precision:
#
#     Purpose: Measures the ratio of true positive predictions to the total number of predicted positives.
#         Output: The precision of the model's predictions.
#
# Sensitivity:
#
#     Purpose: Measures the ratio of true positive predictions to the total number of actual positives.
#         Output: The sensitivity of the model's predictions.
#
# Specificity:
#
#     Purpose: Measures the ratio of true negative predictions to the total number of actual negatives.
#
#               Output: The specificity of the model's predictions.
#
# Key Points
#
#     K: This refers to the backend functions from tensorflow.keras.backend, which include operations such as K.sum and K.flatten.
#     K.epsilon(): A small constant used to prevent division by zero.
#     Compatibility with TensorFlow/Keras: These functions are designed to be used as metrics or loss functions within Keras/TensorFlow models.

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 2
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss

def dice_coef_MS(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)


# Computing Precision
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision


# Computing Sensitivity
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %% [markdown]
#     Defining Data Paths:
#         This part of the code creates a list of directory paths located in the specified dataset path. It filters out only directories and ignores files.
#
#     Removing Directory with Incorrect Name:
#         A specific directory with an incorrectly formatted name for certain files is removed from the list. This step ensures that problematic directories do not interfere with further processing.
#
#     Function to Convert Paths to Identifiers:
#         A function is used to convert directory paths into identifiers, which are typically the names of the directories. This is achieved by extracting the portion of the path after the last /.
#
#     Creating Identifier List and Splitting Data:
#         The list of directory identifiers is created and then split into training and validation sets. The training set is further divided into training and testing sets. The splits are done to allocate data for training the model, validating its performance, and testing its generalization.

# %%
import zipfile
import os
from sklearn.model_selection import train_test_split

# Path to the ZIP file
zip_path = '/content/multiple-sclerosis-2016.zip'
# Directory where the ZIP file will be extracted
extract_to_dir = '/content/multiple-sclerosis-2016/'

# Create the extraction directory if it does not exist
os.makedirs(extract_to_dir, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_dir)

# Update TRAIN_DATASET_PATH to point to the extracted directory
TRAIN_DATASET_PATH = extract_to_dir

# List directories in the extracted path
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# Optionally remove directories with problematic names
# train_and_val_directories = [d for d in train_and_val_directories if 'BraTS20_Training_355' not in d]

def pathListIntoIds(dirList):
    x = []
    for path in dirList:
        x.append(path[path.rfind('/') + 1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories)

# Split the data into training, testing, and validation sets
train_test_ids, val_ids = train_test_split(train_and_test_ids, test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids, test_size=0.15)

print(f"Training IDs: {train_ids}")
print(f"Validation IDs: {val_ids}")
print(f"Testing IDs: {test_ids}")
# Out:
# Training IDs: ['MSSEG2016_TrainingData_Patient_07', 'MSSEG2016_TrainingData_Patient_05', 'MSSEG2016_TrainingData_Patient_10', 'MSSEG2016_TrainingData_Patient_08', 'MSSEG2016_TrainingData_Patient_02', 'MSSEG2016_TrainingData_Patient_09']
# Validation IDs: ['MSSEG2016_TrainingData_Patient_04', 'MSSEG2016_TrainingData_Patient_03']
# Testing IDs: ['MSSEG2016_TrainingData_Patient_06', 'MSSEG2016_TrainingData_Patient_01']

# %%
IMG_SIZE = 128

# %%
tf.keras.utils.Sequence
# Out:
# keras.src.trainers.data_adapters.py_dataset_adapter.PyDataset

# %% [markdown]
# Code Explanation
#
#     Class Definition DataGenerator:
#         This class inherits from tf.keras.utils.Sequence and is used to generate data for training, validation, and testing in Keras.
#
#     Constructor (__init__):
#         Initializes the class variables including image dimensions, batch size, number of channels, and whether to shuffle data.
#
#     Number of Batches per Epoch (__len__):
#         Calculates the number of batches per epoch. This is determined by dividing the total number of IDs by the batch size.
#
#     Generating a Batch of Data (__getitem__):
#         Produces a batch of data. This method determines the indexes for the current batch and generates data for those indexes.
#
#     Updating Indexes After Each Epoch (on_epoch_end):
#         Updates the indexes after each epoch. If shuffle is True, it shuffles the indexes randomly.
#
#     Generating Data (__data_generation):
#         Generates data for a batch. This method:
#             Initializes arrays for input images (X) and labels (y).
#             Loads data and segmentation masks for each item in the batch from the specified paths.
#             Resizes the images and masks to the required dimensions.
#             Converts the labels to one-hot encoded masks and resizes them.
#             Returns normalized input data and one-hot encoded masks.
#
#     Creating Generators:
#         training_generator, valid_generator, and test_generator are defined for training, validation, and testing data, respectively.
#
# Summary
#
# The DataGenerator class is used for generating batches of data for deep learning models in Keras. It handles loading, processing, and preparing data in a way that is suitable for training and evaluation of models.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size =1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization

        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))

        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 256))

        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim,2))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_FLAIR_preprocessed.nii');
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_DP_preprocessed.nii');
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_Consensus.nii');
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];


        # Generate masks
        y[y==0] = 0;

        mask = tf.one_hot(y, 2);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y



training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
# show number of data for each dir
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'orange','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()

showDataLayout()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Code Explanation
#
#     Network Settings:
#         BACKBONE = 'resnet50': Specifies the backbone model to use, which is ResNet50, for the neural network.
#
#     Data Preprocessing:
#         preprocess_input = sm.get_preprocessing(BACKBONE): Retrieves the preprocessing function for the selected backbone model.
#
#     Define Network Parameters:
#         n_classes = 2: Sets the number of output classes (labels) to 2.
#         activation = 'softmax': Specifies the activation function for the output layer as softmax.
#
#     Create Model:
#         model_resnet = sm.Unet(...): Creates a U-Net model using ResNet50 as the backbone. This model is used for image segmentation.
#             classes=n_classes: Number of classes for segmentation.
#             activation=activation: Activation function for the output layer.
#             encoder_weights=None: No pre-trained weights are used for the backbone model.
#             encoder_freeze=True: Freezes the weights of the backbone model to prevent updating them during training.
#             input_shape = (128,128,2): Specifies the input shape of images as 128x128 pixels with 2 channels (e.g., two types of images).
#
#     Compile Model:
#         model_resnet.compile(...): Compiles the Keras model with the specified optimizer, loss function, and evaluation metrics.
#             loss="categorical_crossentropy": The loss function for multi-class classification.
#             optimizer=tf.keras.optimizers.SGD(...): Uses the Stochastic Gradient Descent optimizer with a learning rate of 0.0001 and momentum of 0.1.
#             metrics = [...]: Evaluation metrics include accuracy, Mean Intersection over Union (MeanIoU) with 2 classes, and custom metrics such as dice coefficient, precision, sensitivity, and specificity.
#
# This code sets up and compiles a U-Net model with ResNet50 as the backbone, preparing it for training with the specified parameters and metrics.

# %%
BACKBONE = 'resnet50'

preprocess_input = sm.get_preprocessing(BACKBONE)

# define network parameters
n_classes = 2
activation = 'softmax'

#create model
model_resnet = sm.Unet(BACKBONE, classes=n_classes, activation=activation, encoder_weights=None, encoder_freeze=True, input_shape = (128,128,2))


# compile keras model with defined optimozer, loss and metrics
model_resnet.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001,momentum=0.1),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=2), dice_coef,precision, sensitivity, specificity] )

# %%
model_resnet.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ data (InputLayer)         │ (None, 128, 128, 2)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_data                   │ (None, 128, 128, 2)    │              6 │ data[0][0]             │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 134, 134, 2)    │              0 │ bn_data[0][0]          │
# ...

# %% [markdown]
# Code Explanation
#
#     Loading the Model:
#         model = keras.models.load_model(...): Loads a deep learning model from the file Resnet.h5.
#             r'../input/weights-resnet/Resnet.h5': Path to the saved model file.
#             custom_objects={ ... }: Custom objects used in the model, including evaluation metrics such as:
#                 'accuracy': Accuracy metric using Mean Intersection over Union (MeanIoU) with 2 classes.
#                 "dice_coef": Dice coefficient function.
#                 "precision": Precision function.
#                 "sensitivity": Sensitivity function.
#                 "specificity": Specificity function.
#             compile=False: Indicates that the model does not need to be recompiled.
#
#     Reading Training History:
#         history = pd.read_csv(...): Reads the training history of the model from the file RESNET.log.
#             r'../input/weights-resnet/RESNET.log': Path to the training history file.
#             sep=',': Specifies that the data is separated by commas.
#             engine='python': Uses the Python engine for reading the file.
#
# This code allows you to load a saved model and read its training history for review and analysis.

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
import os
import cv2
import nibabel as nib

# پارامترهای مورد نیاز
IMG_SIZE = 128  # اندازه تصویر ورودی
VOLUME_SLICES = 180
VOLUME_START_AT = 260
TRAIN_DATASET_PATH = '/content/multiple-sclerosis-2016/'

# تعریف کلاس DataGenerator
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, list_IDs, dim=(IMG_SIZE, IMG_SIZE), batch_size=1, n_channels=2, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        Batch_ids = [self.list_IDs[k] for k in indexes]
        X, y = self.__data_generation(Batch_ids)
        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        X = np.zeros((self.batch_size * VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size * VOLUME_SLICES, 240, 256))
        Y = np.zeros((self.batch_size * VOLUME_SLICES, *self.dim, 2))

        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_FLAIR_preprocessed.nii')
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_DP_preprocessed.nii')
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_Consensus.nii')
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                X[j + VOLUME_SLICES * c, :, :, 0] = cv2.resize(flair[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                X[j + VOLUME_SLICES * c, :, :, 1] = cv2.resize(ce[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                y[j + VOLUME_SLICES * c] = seg[:, :, j + VOLUME_START_AT]

        y[y == 0] = 0
        mask = tf.one_hot(y, 2)
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        return X / np.max(X), Y

# لیست‌های ID برای آموزش، اعتبارسنجی و تست
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]
train_and_test_ids = [f.path.split('/')[-1] for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]
train_test_ids, val_ids = train_test_split(train_and_test_ids, test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids, test_size=0.15)

# ایجاد ژنراتورها
train_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
import segmentation_models as sm
import tensorflow as tf
from tensorflow.keras import backend as K

# تعریف مدل ResNet50 به صورت دستی
BACKBONE = 'resnet50'
IMG_SIZE = 128  # اندازه تصویر ورودی
n_classes = 2
activation = 'softmax'

# ایجاد مدل UNet با استفاده از ResNet50 به عنوان encoder
model_resnet = sm.Unet(
    backbone_name=BACKBONE,
    classes=n_classes,
    activation=activation,
    encoder_weights=None,  # به جای بارگذاری وزن‌های پیش‌آموزش‌دیده، از وزن‌های تصادفی استفاده می‌شود
    encoder_freeze=True,
    input_shape=(IMG_SIZE, IMG_SIZE, 2)  # تعداد کانال‌های ورودی
)

# کامپایل مدل با اپتیمایزر، تابع هزینه و معیارها
model_resnet.compile(
    loss="categorical_crossentropy",
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001, momentum=0.1),
    metrics=['accuracy', tf.keras.metrics.MeanIoU(num_classes=n_classes), dice_coef, precision, sensitivity, specificity]
)

# آموزش مدل
history = model_resnet.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=20,  # تعداد اپوک‌ها را بر اساس نیاز تغییر دهید
    verbose=1
)

# ارزیابی مدل
results = model_resnet.evaluate(valid_generator)
print('Evaluation results:', results)

# پیش‌بینی با مدل
predictions = model_resnet.predict(test_generator)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 133s 4s/step - accuracy: 0.6343 - dice_coef: 0.3409 - loss: 0.8380 - mean_io_u_6: 0.2501 - precision: 0.6341 - sensitivity: 0.6342 - specificity: 0.6342 - val_accuracy: 0.0147 - val_dice_coef: 0.1138 - val_loss: 2.4830 - val_mean_io_u_6: 0.2502 - val_precision: 0.0147 - val_sensitivity: 0.0147 - val_specificity: 0.0147
# Epoch 2/20
# ...
